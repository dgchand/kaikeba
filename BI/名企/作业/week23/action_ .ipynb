# %%
#!ls /content/drive/MyDrive/Kaikeba/名企/alphago
# %cd /content/drive/MyDrive/Kaikeba/名企/alphago
# Out:
# /content/drive/MyDrive/Kaikeba/名企/alphago

# %%
# !ls
# Out:
# action.ipynb   mcts_alphaZero.py    policy_value_net_pytorch.py
# game.py        mcts_pure.py	    __pycache__
# human_play.py  policy_value_net.py  train.py

# %%
#train.py

# 训练五子棋AI

from __future__ import print_function
import random
import numpy as np
# deque 是一个双端队列
from collections import defaultdict, deque
from game import Board, Game
from mcts_pure import MCTSPlayer as MCTS_Pure # 随机走子策略的AI
from mcts_alphaZero import MCTSPlayer # AlphaGo方式的AI
from policy_value_net_pytorch import PolicyValueNet  # Pytorch

class TrainPipeline():
    def __init__(self, init_model=None):
        # 设置棋盘和游戏的参数
        self.board_width = 10
        self.board_height = 10
        self.n_in_row = 5
        self.board = Board(width=self.board_width,
                           height=self.board_height,
                           n_in_row=self.n_in_row)
        self.game = Game(self.board)
        # 设置训练参数
        self.learn_rate = 2e-3 # 基准学习率
        self.lr_multiplier = 1.0  # 基于KL自动调整学习倍速
        self.temp = 1.0  # 温度参数
        self.n_playout = 400  # 每下一步棋，模拟的步骤数
        self.c_puct = 5 # exploitation和exploration之间的折中系数
        self.buffer_size = 10000
        self.batch_size = 256 #32  # mini-batch size for training
        self.data_buffer = deque(maxlen=self.buffer_size) #使用 deque 创建一个双端队列
        self.play_batch_size = 1
        self.epochs = 5  # num of train_steps for each update
        self.kl_targ = 0.02 # 早停检查
        self.check_freq = 50 # 每50次检查一次，策略价值网络是否更新
        self.game_batch_num = 250 #500 # 训练多少个epoch
        self.best_win_ratio = 0.0 # 当前最佳胜率，用他来判断是否有更好的模型
        # 弱AI（纯MCTS）模拟步数，用于给训练的策略AI提供对手
        self.pure_mcts_playout_num = 1000
        if init_model:
            # 通过init_model设置策略网络
            self.policy_value_net = PolicyValueNet(self.board_width, self.board_height, model_file=init_model)
        else:
            # 训练一个新的策略网络
            self.policy_value_net = PolicyValueNet(self.board_width, self.board_height)
        # AI Player，设置is_selfplay=1 自我对弈，因为是在进行训练
        self.mcts_player = MCTSPlayer(self.policy_value_net.policy_value_fn,
                                      c_puct=self.c_puct,
                                      n_playout=self.n_playout,
                                      is_selfplay=1)
        
    # 通过旋转和翻转增加数据集, play_data: [(state, mcts_prob, winner_z), ..., ...]
    def get_equi_data(self, play_data):
        extend_data = []
        for state, mcts_porb, winner in play_data:
            # 在4个方向上进行expand，每个方向都进行旋转，水平翻转
            for i in [1, 2, 3, 4]:
                # 逆时针旋转
                equi_state = np.array([np.rot90(s, i) for s in state])
                equi_mcts_prob = np.rot90(np.flipud(mcts_porb.reshape(self.board_height, self.board_width)), i)
                extend_data.append((equi_state, np.flipud(equi_mcts_prob).flatten(), winner))
                # 水平翻转
                equi_state = np.array([np.fliplr(s) for s in equi_state])
                equi_mcts_prob = np.fliplr(equi_mcts_prob)
                extend_data.append((equi_state, np.flipud(equi_mcts_prob).flatten(), winner))
        return extend_data

    # 收集自我对弈数据，用于训练
    def collect_selfplay_data(self, n_games=1):
        for i in range(n_games):
            # 与MCTS Player进行对弈
            winner, play_data = self.game.start_self_play(self.mcts_player, temp=self.temp)
            play_data = list(play_data)[:]
            # 保存下了多少步
            self.episode_len = len(play_data)
            # 增加数据 play_data
            play_data = self.get_equi_data(play_data)
            self.data_buffer.extend(play_data)
            
    # 更新策略网络
    def policy_update(self):
        mini_batch = random.sample(self.data_buffer, self.batch_size)
        state_batch = [data[0] for data in mini_batch]
        mcts_probs_batch = [data[1] for data in mini_batch]
        winner_batch = [data[2] for data in mini_batch]
        # 保存更新前的old_probs, old_v
        old_probs, old_v = self.policy_value_net.policy_value(state_batch)
        for i in range(self.epochs):
            # 每次训练，调整参数，返回loss和entropy
            loss, entropy = self.policy_value_net.train_step(
                    state_batch,
                    mcts_probs_batch,
                    winner_batch,
                    self.learn_rate*self.lr_multiplier)
            # 输入状态，得到行动的可能性和状态值，按照batch进行输入
            new_probs, new_v = self.policy_value_net.policy_value(state_batch)
            # 计算更新前后两次的loss差
            kl = np.mean(np.sum(old_probs * (
                    np.log(old_probs + 1e-10) - np.log(new_probs + 1e-10)),
                    axis=1)
            )
            if kl > self.kl_targ * 4:  # early stopping if D_KL diverges badly
                break
        # 动态调整学习倍率 lr_multiplier
        if kl > self.kl_targ * 2 and self.lr_multiplier > 0.1:
            self.lr_multiplier /= 1.5
        elif kl < self.kl_targ / 2 and self.lr_multiplier < 10:
            self.lr_multiplier *= 1.5

        explained_var_old = (1 -
                             np.var(np.array(winner_batch) - old_v.flatten()) /
                             np.var(np.array(winner_batch)))
        explained_var_new = (1 -
                             np.var(np.array(winner_batch) - new_v.flatten()) /
                             np.var(np.array(winner_batch)))
        print(("kl:{:.5f},"
               "lr_multiplier:{:.3f},"
               "loss:{},"
               "entropy:{},"
               "explained_var_old:{:.3f},"
               "explained_var_new:{:.3f}"
               ).format(kl,
                        self.lr_multiplier,
                        loss,
                        entropy,
                        explained_var_old,
                        explained_var_new))
        return loss, entropy

    # 用于评估训练网络的质量，评估一共10场play，返回比赛胜率（赢1分、输0分、平0.5分）
    def policy_evaluate(self, n_games=10):
        current_mcts_player = MCTSPlayer(self.policy_value_net.policy_value_fn,
                                         c_puct=self.c_puct, n_playout=self.n_playout)
        pure_mcts_player = MCTS_Pure(c_puct=5, n_playout=self.pure_mcts_playout_num)
        win_cnt = defaultdict(int)
        for i in range(n_games):
            # AI和弱AI（纯MCTS）对弈，不需要可视化 is_shown=0，双方轮流职黑 start_player=i % 2
            winner = self.game.start_play(current_mcts_player, pure_mcts_player, start_player=i % 2, is_shown=0)
            win_cnt[winner] += 1
        # 计算胜率，平手计为0.5分
        win_ratio = 1.0*(win_cnt[1] + 0.5*win_cnt[-1]) / n_games
        print("num_playouts:{}, win: {}, lose: {}, tie:{}".format(
                self.pure_mcts_playout_num,
                win_cnt[1], win_cnt[2], win_cnt[-1]))
        return win_ratio

    def run(self):
        # 开始训练
        try:
            # 训练game_batch_num次，每个batch比赛play_batch_size场
            for i in range(self.game_batch_num):
                # 收集自我对弈数据
                self.collect_selfplay_data(self.play_batch_size)
                print("batch i:{}, episode_len:{}".format(i+1, self.episode_len))
                if len(self.data_buffer) > self.batch_size:
                    loss, entropy = self.policy_update()
                # 判断当前模型的表现，保存最优模型
                if (i+1) % self.check_freq == 0:
                    print("current self-play batch: {}".format(i+1))
                    win_ratio = self.policy_evaluate()
                    # 保存当前策略
                    self.policy_value_net.save_model('./current_policy.model')
                    if win_ratio > self.best_win_ratio:
                        print("发现新的最优策略，进行策略更新")
                        self.best_win_ratio = win_ratio
                        # 更新最优策略
                        self.policy_value_net.save_model('./best_policy.model')
                        if (self.best_win_ratio == 1.0 and
                                self.pure_mcts_playout_num < 5000):
                            self.pure_mcts_playout_num += 1000
                            self.best_win_ratio = 0.0
        except KeyboardInterrupt:
            print('\n\rquit')


if __name__ == '__main__':
    training_pipeline = TrainPipeline()
    training_pipeline.run()
# Out:
# /content/drive/My Drive/Kaikeba/名企/alphago/policy_value_net_pytorch.py:45: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   x_act = F.log_softmax(self.act_fc1(x_act))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1698: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# batch i:1, episode_len:61
# kl:0.03068,lr_multiplier:1.000,loss:5.4457292556762695,entropy:4.587529182434082,explained_var_old:0.000,explained_var_new:0.369
# batch i:2, episode_len:41
# kl:0.01449,lr_multiplier:1.000,loss:4.9476637840271,entropy:4.53954553604126,explained_var_old:0.371,explained_var_new:0.759
# batch i:3, episode_len:33
# kl:0.01642,lr_multiplier:1.000,loss:4.897859573364258,entropy:4.491881370544434,explained_var_old:0.759,explained_var_new:0.797
# batch i:4, episode_len:25
# kl:0.08380,lr_multiplier:0.667,loss:4.786677360534668,entropy:4.423091888427734,explained_var_old:0.797,explained_var_new:0.804
# batch i:5, episode_len:37
# kl:0.03299,lr_multiplier:0.667,loss:4.716670513153076,entropy:4.449075222015381,explained_var_old:0.804,explained_var_new:0.814
# batch i:6, episode_len:31
# kl:0.01653,lr_multiplier:0.667,loss:4.585744857788086,entropy:4.302212715148926,explained_var_old:0.814,explained_var_new:0.824
# batch i:7, episode_len:23
# kl:0.07074,lr_multiplier:0.444,loss:4.580957412719727,entropy:4.120403289794922,explained_var_old:0.824,explained_var_new:0.835
# batch i:8, episode_len:49
# kl:0.02160,lr_multiplier:0.444,loss:4.55111026763916,entropy:4.278674125671387,explained_var_old:0.835,explained_var_new:0.835
# batch i:9, episode_len:37
# kl:0.01078,lr_multiplier:0.444,loss:4.501586437225342,entropy:4.159135818481445,explained_var_old:0.835,explained_var_new:0.847
# batch i:10, episode_len:37
# kl:0.01662,lr_multiplier:0.444,loss:4.399740695953369,entropy:4.077213764190674,explained_var_old:0.847,explained_var_new:0.857
# batch i:11, episode_len:21
# kl:0.00943,lr_multiplier:0.667,loss:4.387580394744873,entropy:4.149611473083496,explained_var_old:0.857,explained_var_new:0.865
# batch i:12, episode_len:42
# kl:0.01369,lr_multiplier:0.667,loss:4.560709476470947,entropy:4.032388210296631,explained_var_old:0.568,explained_var_new:0.571
# batch i:13, episode_len:49
# kl:0.01254,lr_multiplier:0.667,loss:4.5559401512146,entropy:4.042674541473389,explained_var_old:0.643,explained_var_new:0.647
# batch i:14, episode_len:41
# kl:0.01491,lr_multiplier:0.667,loss:4.563816547393799,entropy:4.0948805809021,explained_var_old:0.638,explained_var_new:0.642
# batch i:15, episode_len:39
# kl:0.00617,lr_multiplier:1.000,loss:4.483865737915039,entropy:4.136916637420654,explained_var_old:0.728,explained_var_new:0.733
# batch i:16, episode_len:38
# kl:0.02267,lr_multiplier:1.000,loss:4.556788921356201,entropy:4.063138484954834,explained_var_old:0.577,explained_var_new:0.579
# batch i:17, episode_len:40
# kl:0.03359,lr_multiplier:1.000,loss:4.746377468109131,entropy:4.073709487915039,explained_var_old:0.330,explained_var_new:0.288
# batch i:18, episode_len:43
# kl:0.05437,lr_multiplier:0.667,loss:4.650179862976074,entropy:4.045646667480469,explained_var_old:0.236,explained_var_new:0.335
# batch i:19, episode_len:34
# kl:0.02455,lr_multiplier:0.667,loss:4.57860803604126,entropy:3.9945626258850098,explained_var_old:0.345,explained_var_new:0.353
# batch i:20, episode_len:35
# kl:0.03010,lr_multiplier:0.667,loss:4.6144938468933105,entropy:3.9717822074890137,explained_var_old:0.305,explained_var_new:0.309
# batch i:21, episode_len:25
# kl:0.03169,lr_multiplier:0.667,loss:4.386229515075684,entropy:3.925441026687622,explained_var_old:0.494,explained_var_new:0.506
# batch i:22, episode_len:42
# kl:0.02785,lr_multiplier:0.667,loss:4.583793640136719,entropy:3.8738956451416016,explained_var_old:0.247,explained_var_new:0.261
# batch i:23, episode_len:31
# kl:0.02298,lr_multiplier:0.667,loss:4.560445308685303,entropy:3.806126117706299,explained_var_old:0.256,explained_var_new:0.276
# batch i:24, episode_len:33
# kl:0.03319,lr_multiplier:0.667,loss:4.626278877258301,entropy:3.857822895050049,explained_var_old:0.233,explained_var_new:0.240
# batch i:25, episode_len:46
# kl:0.03034,lr_multiplier:0.667,loss:4.593773365020752,entropy:3.8673558235168457,explained_var_old:0.260,explained_var_new:0.273
# batch i:26, episode_len:25
# kl:0.03108,lr_multiplier:0.667,loss:4.539113998413086,entropy:3.882373809814453,explained_var_old:0.347,explained_var_new:0.365
# batch i:27, episode_len:15
# kl:0.03696,lr_multiplier:0.667,loss:4.537008285522461,entropy:3.8156776428222656,explained_var_old:0.274,explained_var_new:0.301
# batch i:28, episode_len:21
# kl:0.03303,lr_multiplier:0.667,loss:4.540465831756592,entropy:3.8236472606658936,explained_var_old:0.296,explained_var_new:0.302
# batch i:29, episode_len:21
# kl:0.03976,lr_multiplier:0.667,loss:4.442304611206055,entropy:3.770967483520508,explained_var_old:0.336,explained_var_new:0.358
# batch i:30, episode_len:21
# kl:0.04485,lr_multiplier:0.444,loss:4.416813850402832,entropy:3.8682076930999756,explained_var_old:0.391,explained_var_new:0.422
# batch i:31, episode_len:17
# kl:0.01218,lr_multiplier:0.444,loss:4.522030830383301,entropy:3.9117774963378906,explained_var_old:0.334,explained_var_new:0.357
# batch i:32, episode_len:22
# kl:0.01987,lr_multiplier:0.444,loss:4.475385665893555,entropy:3.8624014854431152,explained_var_old:0.352,explained_var_new:0.386
# batch i:33, episode_len:17
# kl:0.02476,lr_multiplier:0.444,loss:4.477929592132568,entropy:3.7888753414154053,explained_var_old:0.306,explained_var_new:0.328
# batch i:34, episode_len:27
# kl:0.02420,lr_multiplier:0.444,loss:4.533287525177002,entropy:3.8907060623168945,explained_var_old:0.284,explained_var_new:0.363
# batch i:35, episode_len:41
# kl:0.01714,lr_multiplier:0.444,loss:4.4980034828186035,entropy:3.9822633266448975,explained_var_old:0.432,explained_var_new:0.441
# batch i:36, episode_len:29
# kl:0.03481,lr_multiplier:0.444,loss:4.320550441741943,entropy:3.7320423126220703,explained_var_old:0.270,explained_var_new:0.357
# batch i:37, episode_len:29
# kl:0.01862,lr_multiplier:0.444,loss:4.311951637268066,entropy:3.741225481033325,explained_var_old:0.399,explained_var_new:0.432
# batch i:38, episode_len:43
# kl:0.02148,lr_multiplier:0.444,loss:4.434194564819336,entropy:3.863316774368286,explained_var_old:0.383,explained_var_new:0.406
# batch i:39, episode_len:31
# kl:0.02942,lr_multiplier:0.444,loss:4.2594099044799805,entropy:3.7725026607513428,explained_var_old:0.462,explained_var_new:0.500
# batch i:40, episode_len:31
# kl:0.02998,lr_multiplier:0.444,loss:4.3312668800354,entropy:3.814525604248047,explained_var_old:0.452,explained_var_new:0.495
# batch i:41, episode_len:22
# kl:0.04502,lr_multiplier:0.296,loss:4.347900867462158,entropy:3.7360727787017822,explained_var_old:0.292,explained_var_new:0.400
# batch i:42, episode_len:31
# kl:0.03397,lr_multiplier:0.296,loss:4.2270331382751465,entropy:3.8434407711029053,explained_var_old:0.536,explained_var_new:0.573
# batch i:43, episode_len:21
# kl:0.01391,lr_multiplier:0.296,loss:4.168982982635498,entropy:3.72568416595459,explained_var_old:0.494,explained_var_new:0.523
# batch i:44, episode_len:54
# kl:0.01820,lr_multiplier:0.296,loss:4.353459358215332,entropy:3.7659292221069336,explained_var_old:0.362,explained_var_new:0.420
# batch i:45, episode_len:29
# kl:0.02475,lr_multiplier:0.296,loss:4.389158725738525,entropy:3.7408876419067383,explained_var_old:0.302,explained_var_new:0.387
# batch i:46, episode_len:30
# kl:0.03453,lr_multiplier:0.296,loss:4.472404479980469,entropy:3.722794532775879,explained_var_old:0.248,explained_var_new:0.270
# batch i:47, episode_len:18
# kl:0.02200,lr_multiplier:0.296,loss:4.231968402862549,entropy:3.657623767852783,explained_var_old:0.345,explained_var_new:0.378
# batch i:48, episode_len:41
# kl:0.01698,lr_multiplier:0.296,loss:4.34084939956665,entropy:3.7105712890625,explained_var_old:0.364,explained_var_new:0.400
# batch i:49, episode_len:25
# kl:0.02075,lr_multiplier:0.296,loss:4.3175129890441895,entropy:3.618112802505493,explained_var_old:0.310,explained_var_new:0.326
# batch i:50, episode_len:25
# kl:0.01122,lr_multiplier:0.296,loss:4.433823108673096,entropy:3.8053362369537354,explained_var_old:0.351,explained_var_new:0.372
# current self-play batch: 50
# num_playouts:1000, win: 2, lose: 8, tie:0
# 发现新的最优策略，进行策略更新
# batch i:51, episode_len:27
# kl:0.01571,lr_multiplier:0.296,loss:4.190557479858398,entropy:3.6440606117248535,explained_var_old:0.406,explained_var_new:0.445
# batch i:52, episode_len:29
# kl:0.01286,lr_multiplier:0.296,loss:4.352242469787598,entropy:3.736142158508301,explained_var_old:0.300,explained_var_new:0.370
# batch i:53, episode_len:25
# kl:0.01178,lr_multiplier:0.296,loss:4.244662284851074,entropy:3.7017927169799805,explained_var_old:0.379,explained_var_new:0.430
# batch i:54, episode_len:29
# kl:0.01196,lr_multiplier:0.296,loss:4.219288349151611,entropy:3.6119601726531982,explained_var_old:0.389,explained_var_new:0.396
# batch i:55, episode_len:44
# kl:0.00836,lr_multiplier:0.444,loss:4.402276039123535,entropy:3.719801902770996,explained_var_old:0.220,explained_var_new:0.304
# batch i:56, episode_len:27
# kl:0.03541,lr_multiplier:0.444,loss:4.332049369812012,entropy:3.740147113800049,explained_var_old:0.273,explained_var_new:0.357
# batch i:57, episode_len:21
# kl:0.03690,lr_multiplier:0.444,loss:4.391836643218994,entropy:3.641369581222534,explained_var_old:0.194,explained_var_new:0.281
# batch i:58, episode_len:37
# kl:0.02768,lr_multiplier:0.444,loss:4.446889877319336,entropy:3.766528367996216,explained_var_old:0.294,explained_var_new:0.322
# batch i:59, episode_len:27
# kl:0.06749,lr_multiplier:0.296,loss:4.157658100128174,entropy:3.7039828300476074,explained_var_old:0.461,explained_var_new:0.493
# batch i:60, episode_len:33
# kl:0.01877,lr_multiplier:0.296,loss:4.26456356048584,entropy:3.6725335121154785,explained_var_old:0.343,explained_var_new:0.401
# batch i:61, episode_len:31
# kl:0.02101,lr_multiplier:0.296,loss:4.2681884765625,entropy:3.622671365737915,explained_var_old:0.305,explained_var_new:0.344
# batch i:62, episode_len:23
# kl:0.02759,lr_multiplier:0.296,loss:4.0926666259765625,entropy:3.548633098602295,explained_var_old:0.334,explained_var_new:0.365
# batch i:63, episode_len:15
# kl:0.02060,lr_multiplier:0.296,loss:4.18560791015625,entropy:3.640967607498169,explained_var_old:0.411,explained_var_new:0.425
# batch i:64, episode_len:38
# kl:0.01609,lr_multiplier:0.296,loss:4.386421203613281,entropy:3.767611265182495,explained_var_old:0.339,explained_var_new:0.395
# batch i:65, episode_len:31
# kl:0.01385,lr_multiplier:0.296,loss:4.201099395751953,entropy:3.7460455894470215,explained_var_old:0.510,explained_var_new:0.542
# batch i:66, episode_len:38
# kl:0.01367,lr_multiplier:0.296,loss:4.297729015350342,entropy:3.6751246452331543,explained_var_old:0.322,explained_var_new:0.375
# batch i:67, episode_len:35
# kl:0.03073,lr_multiplier:0.296,loss:4.1973876953125,entropy:3.5859200954437256,explained_var_old:0.365,explained_var_new:0.423
# batch i:68, episode_len:33
# kl:0.03275,lr_multiplier:0.296,loss:4.335965633392334,entropy:3.722939968109131,explained_var_old:0.391,explained_var_new:0.399
# batch i:69, episode_len:43
# kl:0.01662,lr_multiplier:0.296,loss:4.076901435852051,entropy:3.5986132621765137,explained_var_old:0.433,explained_var_new:0.479
# batch i:70, episode_len:25
# kl:0.01665,lr_multiplier:0.296,loss:4.15640926361084,entropy:3.662095308303833,explained_var_old:0.441,explained_var_new:0.468
# batch i:71, episode_len:37
# kl:0.00879,lr_multiplier:0.444,loss:4.250311374664307,entropy:3.6751646995544434,explained_var_old:0.352,explained_var_new:0.390
# batch i:72, episode_len:39
# kl:0.01502,lr_multiplier:0.444,loss:4.268427848815918,entropy:3.6797306537628174,explained_var_old:0.433,explained_var_new:0.446
# batch i:73, episode_len:29
# kl:0.04305,lr_multiplier:0.296,loss:3.9520092010498047,entropy:3.502079486846924,explained_var_old:0.481,explained_var_new:0.501
# batch i:74, episode_len:27
# kl:0.01521,lr_multiplier:0.296,loss:4.267271995544434,entropy:3.7595863342285156,explained_var_old:0.463,explained_var_new:0.495
# batch i:75, episode_len:32
# kl:0.01247,lr_multiplier:0.296,loss:4.101292610168457,entropy:3.633143901824951,explained_var_old:0.458,explained_var_new:0.484
# batch i:76, episode_len:31
# kl:0.01238,lr_multiplier:0.296,loss:4.1618123054504395,entropy:3.675821304321289,explained_var_old:0.459,explained_var_new:0.494
# batch i:77, episode_len:31
# kl:0.01126,lr_multiplier:0.296,loss:4.319906711578369,entropy:3.713747978210449,explained_var_old:0.369,explained_var_new:0.400
# batch i:78, episode_len:34
# kl:0.01504,lr_multiplier:0.296,loss:3.990837574005127,entropy:3.551785469055176,explained_var_old:0.472,explained_var_new:0.507
# batch i:79, episode_len:33
# kl:0.02106,lr_multiplier:0.296,loss:4.162332057952881,entropy:3.527944564819336,explained_var_old:0.360,explained_var_new:0.374
# batch i:80, episode_len:33
# kl:0.02433,lr_multiplier:0.296,loss:4.227930545806885,entropy:3.609128713607788,explained_var_old:0.351,explained_var_new:0.395
# batch i:81, episode_len:23
# kl:0.03032,lr_multiplier:0.296,loss:4.077624320983887,entropy:3.5573737621307373,explained_var_old:0.469,explained_var_new:0.480
# batch i:82, episode_len:21
# kl:0.03708,lr_multiplier:0.296,loss:4.290672779083252,entropy:3.6581249237060547,explained_var_old:0.256,explained_var_new:0.388
# batch i:83, episode_len:39
# kl:0.03427,lr_multiplier:0.296,loss:4.296726703643799,entropy:3.685178279876709,explained_var_old:0.336,explained_var_new:0.369
# batch i:84, episode_len:25
# kl:0.01745,lr_multiplier:0.296,loss:4.106416702270508,entropy:3.632136821746826,explained_var_old:0.481,explained_var_new:0.506
# batch i:85, episode_len:21
# kl:0.01748,lr_multiplier:0.296,loss:4.131854057312012,entropy:3.6017096042633057,explained_var_old:0.450,explained_var_new:0.474
# batch i:86, episode_len:27
# kl:0.02262,lr_multiplier:0.296,loss:4.070679664611816,entropy:3.586094379425049,explained_var_old:0.481,explained_var_new:0.504
# batch i:87, episode_len:39
# kl:0.01601,lr_multiplier:0.296,loss:4.146605968475342,entropy:3.662184000015259,explained_var_old:0.475,explained_var_new:0.536
# batch i:88, episode_len:49
# kl:0.02117,lr_multiplier:0.296,loss:3.892329216003418,entropy:3.506667137145996,explained_var_old:0.566,explained_var_new:0.617
# batch i:89, episode_len:25
# kl:0.01283,lr_multiplier:0.296,loss:4.1113128662109375,entropy:3.648013114929199,explained_var_old:0.499,explained_var_new:0.533
# batch i:90, episode_len:25
# kl:0.00834,lr_multiplier:0.444,loss:4.0041279792785645,entropy:3.5749194622039795,explained_var_old:0.513,explained_var_new:0.544
# batch i:91, episode_len:27
# kl:0.02947,lr_multiplier:0.444,loss:3.9401867389678955,entropy:3.6129531860351562,explained_var_old:0.631,explained_var_new:0.649
# batch i:92, episode_len:27
# kl:0.03720,lr_multiplier:0.444,loss:3.959763526916504,entropy:3.6150221824645996,explained_var_old:0.619,explained_var_new:0.653
# batch i:93, episode_len:31
# kl:0.03823,lr_multiplier:0.444,loss:3.8525304794311523,entropy:3.5058648586273193,explained_var_old:0.580,explained_var_new:0.610
# batch i:94, episode_len:29
# kl:0.04499,lr_multiplier:0.296,loss:3.82353138923645,entropy:3.4177284240722656,explained_var_old:0.581,explained_var_new:0.624
# batch i:95, episode_len:29
# kl:0.02753,lr_multiplier:0.296,loss:3.9352495670318604,entropy:3.510000705718994,explained_var_old:0.497,explained_var_new:0.537
# batch i:96, episode_len:31
# kl:0.02495,lr_multiplier:0.296,loss:3.8747830390930176,entropy:3.6181862354278564,explained_var_old:0.710,explained_var_new:0.736
# batch i:97, episode_len:32
# kl:0.05895,lr_multiplier:0.198,loss:4.0711669921875,entropy:3.6585259437561035,explained_var_old:0.573,explained_var_new:0.599
# batch i:98, episode_len:27
# kl:0.03793,lr_multiplier:0.198,loss:4.027998447418213,entropy:3.62703275680542,explained_var_old:0.535,explained_var_new:0.578
# batch i:99, episode_len:37
# kl:0.01432,lr_multiplier:0.198,loss:3.8835935592651367,entropy:3.586331844329834,explained_var_old:0.664,explained_var_new:0.677
# batch i:100, episode_len:31
# kl:0.00659,lr_multiplier:0.296,loss:3.87064266204834,entropy:3.5452969074249268,explained_var_old:0.608,explained_var_new:0.625
# current self-play batch: 100
# num_playouts:1000, win: 4, lose: 6, tie:0
# 发现新的最优策略，进行策略更新
# batch i:101, episode_len:15
# kl:0.01535,lr_multiplier:0.296,loss:3.857362985610962,entropy:3.497783660888672,explained_var_old:0.604,explained_var_new:0.636
# batch i:102, episode_len:37
# kl:0.01477,lr_multiplier:0.296,loss:3.978867769241333,entropy:3.6497621536254883,explained_var_old:0.626,explained_var_new:0.650
# batch i:103, episode_len:41
# kl:0.02176,lr_multiplier:0.296,loss:3.9456732273101807,entropy:3.602705478668213,explained_var_old:0.632,explained_var_new:0.664
# batch i:104, episode_len:24
# kl:0.02132,lr_multiplier:0.296,loss:3.762152671813965,entropy:3.467623710632324,explained_var_old:0.649,explained_var_new:0.678
# batch i:105, episode_len:37
# kl:0.01528,lr_multiplier:0.296,loss:3.985243558883667,entropy:3.6462063789367676,explained_var_old:0.647,explained_var_new:0.668
# batch i:106, episode_len:25
# kl:0.02021,lr_multiplier:0.296,loss:3.785454511642456,entropy:3.527019500732422,explained_var_old:0.652,explained_var_new:0.692
# batch i:107, episode_len:27
# kl:0.02740,lr_multiplier:0.296,loss:3.801915407180786,entropy:3.6098358631134033,explained_var_old:0.740,explained_var_new:0.777
# batch i:108, episode_len:28
# kl:0.02484,lr_multiplier:0.296,loss:3.84934663772583,entropy:3.579784393310547,explained_var_old:0.658,explained_var_new:0.712
# batch i:109, episode_len:25
# kl:0.04043,lr_multiplier:0.198,loss:3.88091778755188,entropy:3.493170738220215,explained_var_old:0.601,explained_var_new:0.635
# batch i:110, episode_len:34
# kl:0.02592,lr_multiplier:0.198,loss:3.82832670211792,entropy:3.4972002506256104,explained_var_old:0.628,explained_var_new:0.660
# batch i:111, episode_len:25
# kl:0.01161,lr_multiplier:0.198,loss:3.846937894821167,entropy:3.496427059173584,explained_var_old:0.613,explained_var_new:0.642
# batch i:112, episode_len:29
# kl:0.01320,lr_multiplier:0.198,loss:3.946174144744873,entropy:3.4839656352996826,explained_var_old:0.489,explained_var_new:0.526
# batch i:113, episode_len:29
# kl:0.01217,lr_multiplier:0.198,loss:3.968132972717285,entropy:3.6120481491088867,explained_var_old:0.594,explained_var_new:0.629
# batch i:114, episode_len:27
# kl:0.02163,lr_multiplier:0.198,loss:3.9206361770629883,entropy:3.5404913425445557,explained_var_old:0.608,explained_var_new:0.616
# batch i:115, episode_len:17
# kl:0.01797,lr_multiplier:0.198,loss:3.8657853603363037,entropy:3.546647071838379,explained_var_old:0.609,explained_var_new:0.638
# batch i:116, episode_len:27
# kl:0.02885,lr_multiplier:0.198,loss:3.693378448486328,entropy:3.3456850051879883,explained_var_old:0.597,explained_var_new:0.623
# batch i:117, episode_len:23
# kl:0.00880,lr_multiplier:0.296,loss:3.764474391937256,entropy:3.5099337100982666,explained_var_old:0.694,explained_var_new:0.715
# batch i:118, episode_len:25
# kl:0.01810,lr_multiplier:0.296,loss:3.855586051940918,entropy:3.6348752975463867,explained_var_old:0.703,explained_var_new:0.733
# batch i:119, episode_len:33
# kl:0.03251,lr_multiplier:0.296,loss:3.7728962898254395,entropy:3.499302387237549,explained_var_old:0.689,explained_var_new:0.697
# batch i:120, episode_len:34
# kl:0.01746,lr_multiplier:0.296,loss:3.72633957862854,entropy:3.392174005508423,explained_var_old:0.620,explained_var_new:0.652
# batch i:121, episode_len:31
# kl:0.03366,lr_multiplier:0.296,loss:3.727062702178955,entropy:3.4461727142333984,explained_var_old:0.697,explained_var_new:0.738
# batch i:122, episode_len:39
# kl:0.01883,lr_multiplier:0.296,loss:3.860168933868408,entropy:3.5785934925079346,explained_var_old:0.633,explained_var_new:0.688
# batch i:123, episode_len:25
# kl:0.01175,lr_multiplier:0.296,loss:3.7640089988708496,entropy:3.573392391204834,explained_var_old:0.716,explained_var_new:0.738
# batch i:124, episode_len:23
# kl:0.01540,lr_multiplier:0.296,loss:3.876509189605713,entropy:3.557527542114258,explained_var_old:0.631,explained_var_new:0.665
# batch i:125, episode_len:17
# kl:0.01667,lr_multiplier:0.296,loss:3.6361560821533203,entropy:3.386643886566162,explained_var_old:0.711,explained_var_new:0.731
# batch i:126, episode_len:27
# kl:0.02677,lr_multiplier:0.296,loss:3.6700029373168945,entropy:3.424938678741455,explained_var_old:0.707,explained_var_new:0.737
# batch i:127, episode_len:39
# kl:0.02162,lr_multiplier:0.296,loss:3.72078275680542,entropy:3.4453206062316895,explained_var_old:0.665,explained_var_new:0.711
# batch i:128, episode_len:25
# kl:0.02377,lr_multiplier:0.296,loss:3.7115533351898193,entropy:3.5001630783081055,explained_var_old:0.747,explained_var_new:0.767
# batch i:129, episode_len:34
# kl:0.02633,lr_multiplier:0.296,loss:3.802046775817871,entropy:3.408651828765869,explained_var_old:0.581,explained_var_new:0.643
# batch i:130, episode_len:43
# kl:0.02111,lr_multiplier:0.296,loss:3.853684902191162,entropy:3.522087812423706,explained_var_old:0.612,explained_var_new:0.647
# batch i:131, episode_len:25
# kl:0.02843,lr_multiplier:0.296,loss:3.7893478870391846,entropy:3.433570384979248,explained_var_old:0.616,explained_var_new:0.652
# batch i:132, episode_len:24
# kl:0.02661,lr_multiplier:0.296,loss:3.8996355533599854,entropy:3.4472384452819824,explained_var_old:0.488,explained_var_new:0.527
# batch i:133, episode_len:19
# kl:0.01811,lr_multiplier:0.296,loss:3.8492538928985596,entropy:3.4557929039001465,explained_var_old:0.506,explained_var_new:0.561
# batch i:134, episode_len:27
# kl:0.02295,lr_multiplier:0.296,loss:3.9284310340881348,entropy:3.4903252124786377,explained_var_old:0.454,explained_var_new:0.491
# batch i:135, episode_len:27
# kl:0.02345,lr_multiplier:0.296,loss:3.784183979034424,entropy:3.416386127471924,explained_var_old:0.520,explained_var_new:0.616
# batch i:136, episode_len:24
# kl:0.02281,lr_multiplier:0.296,loss:3.883690118789673,entropy:3.435300350189209,explained_var_old:0.540,explained_var_new:0.562
# batch i:137, episode_len:29
# kl:0.04478,lr_multiplier:0.198,loss:3.8289990425109863,entropy:3.383045196533203,explained_var_old:0.463,explained_var_new:0.526
# batch i:138, episode_len:18
# kl:0.02670,lr_multiplier:0.198,loss:3.9541842937469482,entropy:3.4358954429626465,explained_var_old:0.398,explained_var_new:0.441
# batch i:139, episode_len:31
# kl:0.01419,lr_multiplier:0.198,loss:3.9405922889709473,entropy:3.5024654865264893,explained_var_old:0.517,explained_var_new:0.541
# batch i:140, episode_len:27
# kl:0.02712,lr_multiplier:0.198,loss:3.961198329925537,entropy:3.315145969390869,explained_var_old:0.311,explained_var_new:0.342
# batch i:141, episode_len:23
# kl:0.00858,lr_multiplier:0.296,loss:3.9202213287353516,entropy:3.428535223007202,explained_var_old:0.420,explained_var_new:0.438
# batch i:142, episode_len:27
# kl:0.03196,lr_multiplier:0.296,loss:3.774806499481201,entropy:3.249629497528076,explained_var_old:0.431,explained_var_new:0.474
# batch i:143, episode_len:29
# kl:0.02242,lr_multiplier:0.296,loss:3.732788562774658,entropy:3.2911715507507324,explained_var_old:0.496,explained_var_new:0.532
# batch i:144, episode_len:23
# kl:0.02793,lr_multiplier:0.296,loss:3.822545289993286,entropy:3.31472110748291,explained_var_old:0.466,explained_var_new:0.491
# batch i:145, episode_len:35
# kl:0.04980,lr_multiplier:0.198,loss:3.9085168838500977,entropy:3.437222480773926,explained_var_old:0.473,explained_var_new:0.509
# batch i:146, episode_len:25
# kl:0.02062,lr_multiplier:0.198,loss:3.833406448364258,entropy:3.3896119594573975,explained_var_old:0.500,explained_var_new:0.516
# batch i:147, episode_len:31
# kl:0.01814,lr_multiplier:0.198,loss:3.798956871032715,entropy:3.3953142166137695,explained_var_old:0.564,explained_var_new:0.589
# batch i:148, episode_len:21
# kl:0.02635,lr_multiplier:0.198,loss:3.77702260017395,entropy:3.3619394302368164,explained_var_old:0.528,explained_var_new:0.554
# batch i:149, episode_len:29
# kl:0.02854,lr_multiplier:0.198,loss:3.753476142883301,entropy:3.312427520751953,explained_var_old:0.540,explained_var_new:0.558
# batch i:150, episode_len:23
# kl:0.02289,lr_multiplier:0.198,loss:3.802467107772827,entropy:3.409832239151001,explained_var_old:0.556,explained_var_new:0.579
# current self-play batch: 150
# num_playouts:1000, win: 1, lose: 9, tie:0
# batch i:151, episode_len:25
# kl:0.01213,lr_multiplier:0.198,loss:3.8418455123901367,entropy:3.375615119934082,explained_var_old:0.530,explained_var_new:0.547
# batch i:152, episode_len:29
# kl:0.01179,lr_multiplier:0.198,loss:3.7687902450561523,entropy:3.3879830837249756,explained_var_old:0.557,explained_var_new:0.579
# batch i:153, episode_len:34
# kl:0.01169,lr_multiplier:0.198,loss:3.5901544094085693,entropy:3.232959508895874,explained_var_old:0.562,explained_var_new:0.598
# batch i:154, episode_len:27
# kl:0.01599,lr_multiplier:0.198,loss:3.69728422164917,entropy:3.291398048400879,explained_var_old:0.577,explained_var_new:0.592
# batch i:155, episode_len:31
# kl:0.02438,lr_multiplier:0.198,loss:3.8842568397521973,entropy:3.3749430179595947,explained_var_old:0.445,explained_var_new:0.473
# batch i:156, episode_len:21
# kl:0.01276,lr_multiplier:0.198,loss:3.6975913047790527,entropy:3.3793556690216064,explained_var_old:0.629,explained_var_new:0.650
# batch i:157, episode_len:25
# kl:0.01094,lr_multiplier:0.198,loss:3.8181843757629395,entropy:3.382035255432129,explained_var_old:0.544,explained_var_new:0.559
# batch i:158, episode_len:31
# kl:0.01611,lr_multiplier:0.198,loss:3.750703811645508,entropy:3.2677438259124756,explained_var_old:0.533,explained_var_new:0.556
# batch i:159, episode_len:18
# kl:0.01524,lr_multiplier:0.198,loss:3.8498034477233887,entropy:3.3521533012390137,explained_var_old:0.441,explained_var_new:0.470
# batch i:160, episode_len:24
# kl:0.00898,lr_multiplier:0.296,loss:3.911874294281006,entropy:3.3711137771606445,explained_var_old:0.381,explained_var_new:0.429
# batch i:161, episode_len:25
# kl:0.03024,lr_multiplier:0.296,loss:3.670253038406372,entropy:3.260158061981201,explained_var_old:0.480,explained_var_new:0.546
# batch i:162, episode_len:27
# kl:0.02287,lr_multiplier:0.296,loss:3.8256354331970215,entropy:3.2423741817474365,explained_var_old:0.392,explained_var_new:0.407
# batch i:163, episode_len:33
# kl:0.02294,lr_multiplier:0.296,loss:3.6821234226226807,entropy:3.1982483863830566,explained_var_old:0.481,explained_var_new:0.542
# batch i:164, episode_len:26
# kl:0.02318,lr_multiplier:0.296,loss:3.846827983856201,entropy:3.303612232208252,explained_var_old:0.404,explained_var_new:0.434
# batch i:165, episode_len:28
# kl:0.03557,lr_multiplier:0.296,loss:3.691930055618286,entropy:3.164144992828369,explained_var_old:0.448,explained_var_new:0.502
# batch i:166, episode_len:30
# kl:0.02821,lr_multiplier:0.296,loss:3.857614517211914,entropy:3.2954084873199463,explained_var_old:0.376,explained_var_new:0.408
# batch i:167, episode_len:25
# kl:0.03356,lr_multiplier:0.296,loss:3.735475778579712,entropy:3.2779054641723633,explained_var_old:0.395,explained_var_new:0.464
# batch i:168, episode_len:23
# kl:0.03292,lr_multiplier:0.296,loss:3.8634438514709473,entropy:3.274982213973999,explained_var_old:0.376,explained_var_new:0.418
# batch i:169, episode_len:27
# kl:0.03372,lr_multiplier:0.296,loss:3.671308755874634,entropy:3.2355127334594727,explained_var_old:0.496,explained_var_new:0.531
# batch i:170, episode_len:33
# kl:0.03239,lr_multiplier:0.296,loss:3.764399528503418,entropy:3.278334140777588,explained_var_old:0.429,explained_var_new:0.479
# batch i:171, episode_len:25
# kl:0.03101,lr_multiplier:0.296,loss:3.6218008995056152,entropy:3.189378261566162,explained_var_old:0.498,explained_var_new:0.527
# batch i:172, episode_len:20
# kl:0.05638,lr_multiplier:0.198,loss:3.8171515464782715,entropy:3.2214391231536865,explained_var_old:0.334,explained_var_new:0.410
# batch i:173, episode_len:24
# kl:0.02349,lr_multiplier:0.198,loss:3.6500284671783447,entropy:3.1558802127838135,explained_var_old:0.388,explained_var_new:0.455
# batch i:174, episode_len:23
# kl:0.01975,lr_multiplier:0.198,loss:3.8507895469665527,entropy:3.28507137298584,explained_var_old:0.398,explained_var_new:0.401
# batch i:175, episode_len:28
# kl:0.02454,lr_multiplier:0.198,loss:3.938790798187256,entropy:3.214198350906372,explained_var_old:0.255,explained_var_new:0.322
# batch i:176, episode_len:24
# kl:0.01846,lr_multiplier:0.198,loss:3.923063039779663,entropy:3.325430154800415,explained_var_old:0.347,explained_var_new:0.367
# batch i:177, episode_len:27
# kl:0.01515,lr_multiplier:0.198,loss:3.7414774894714355,entropy:3.110281467437744,explained_var_old:0.313,explained_var_new:0.351
# batch i:178, episode_len:35
# kl:0.01061,lr_multiplier:0.198,loss:3.9070346355438232,entropy:3.3127615451812744,explained_var_old:0.333,explained_var_new:0.356
# batch i:179, episode_len:19
# kl:0.01653,lr_multiplier:0.198,loss:3.763326644897461,entropy:3.187596082687378,explained_var_old:0.340,explained_var_new:0.425
# batch i:180, episode_len:23
# kl:0.01797,lr_multiplier:0.198,loss:3.7656471729278564,entropy:3.182628631591797,explained_var_old:0.390,explained_var_new:0.422
# batch i:181, episode_len:28
# kl:0.01466,lr_multiplier:0.198,loss:3.928713083267212,entropy:3.297006845474243,explained_var_old:0.349,explained_var_new:0.369
# batch i:182, episode_len:23
# kl:0.01939,lr_multiplier:0.198,loss:3.9266974925994873,entropy:3.273517370223999,explained_var_old:0.255,explained_var_new:0.324
# batch i:183, episode_len:25
# kl:0.01291,lr_multiplier:0.198,loss:3.9529573917388916,entropy:3.297848701477051,explained_var_old:0.269,explained_var_new:0.300
# batch i:184, episode_len:32
# kl:0.02236,lr_multiplier:0.198,loss:3.950989246368408,entropy:3.3057117462158203,explained_var_old:0.242,explained_var_new:0.310
# batch i:185, episode_len:23
# kl:0.01716,lr_multiplier:0.198,loss:3.8870291709899902,entropy:3.274686336517334,explained_var_old:0.373,explained_var_new:0.399
# batch i:186, episode_len:19
# kl:0.01278,lr_multiplier:0.198,loss:3.8791162967681885,entropy:3.1745479106903076,explained_var_old:0.272,explained_var_new:0.321
# batch i:187, episode_len:27
# kl:0.02667,lr_multiplier:0.198,loss:3.703331470489502,entropy:3.1408369541168213,explained_var_old:0.380,explained_var_new:0.413
# batch i:188, episode_len:10
# kl:0.01219,lr_multiplier:0.198,loss:3.9844253063201904,entropy:3.323474884033203,explained_var_old:0.273,explained_var_new:0.311
# batch i:189, episode_len:15
# kl:0.01407,lr_multiplier:0.198,loss:3.7928760051727295,entropy:3.2397572994232178,explained_var_old:0.394,explained_var_new:0.422
# batch i:190, episode_len:19
# kl:0.01496,lr_multiplier:0.198,loss:3.628300666809082,entropy:3.0739402770996094,explained_var_old:0.386,explained_var_new:0.420
# batch i:191, episode_len:23
# kl:0.02694,lr_multiplier:0.198,loss:3.7712087631225586,entropy:3.1800479888916016,explained_var_old:0.373,explained_var_new:0.411
# batch i:192, episode_len:14
# kl:0.01311,lr_multiplier:0.198,loss:3.796314001083374,entropy:3.186112403869629,explained_var_old:0.401,explained_var_new:0.424
# batch i:193, episode_len:29
# kl:0.02252,lr_multiplier:0.198,loss:3.6552839279174805,entropy:3.108976364135742,explained_var_old:0.385,explained_var_new:0.433
# batch i:194, episode_len:18
# kl:0.01084,lr_multiplier:0.198,loss:3.7614617347717285,entropy:3.1201088428497314,explained_var_old:0.320,explained_var_new:0.355
# batch i:195, episode_len:14
# kl:0.01127,lr_multiplier:0.198,loss:3.7621827125549316,entropy:3.212181329727173,explained_var_old:0.367,explained_var_new:0.412
# batch i:196, episode_len:22
# kl:0.01693,lr_multiplier:0.198,loss:3.751711130142212,entropy:3.127347230911255,explained_var_old:0.301,explained_var_new:0.338
# batch i:197, episode_len:31
# kl:0.01236,lr_multiplier:0.198,loss:3.6804399490356445,entropy:3.090855836868286,explained_var_old:0.330,explained_var_new:0.370
# batch i:198, episode_len:25
# kl:0.01876,lr_multiplier:0.198,loss:3.678384304046631,entropy:3.114525318145752,explained_var_old:0.379,explained_var_new:0.401
# batch i:199, episode_len:13
# kl:0.03925,lr_multiplier:0.198,loss:3.9031739234924316,entropy:3.193514585494995,explained_var_old:0.323,explained_var_new:0.376
# batch i:200, episode_len:26
# kl:0.02946,lr_multiplier:0.198,loss:3.836822032928467,entropy:3.127702236175537,explained_var_old:0.225,explained_var_new:0.280
# current self-play batch: 200
# num_playouts:1000, win: 5, lose: 5, tie:0
# 发现新的最优策略，进行策略更新
# batch i:201, episode_len:21
# kl:0.04037,lr_multiplier:0.132,loss:3.8237252235412598,entropy:3.16062068939209,explained_var_old:0.276,explained_var_new:0.356
# batch i:202, episode_len:27
# kl:0.01494,lr_multiplier:0.132,loss:3.7814743518829346,entropy:3.190837860107422,explained_var_old:0.358,explained_var_new:0.398
# batch i:203, episode_len:21
# kl:0.01637,lr_multiplier:0.132,loss:3.7688393592834473,entropy:3.1082379817962646,explained_var_old:0.285,explained_var_new:0.339
# batch i:204, episode_len:25
# kl:0.02758,lr_multiplier:0.132,loss:3.6940698623657227,entropy:3.001070976257324,explained_var_old:0.244,explained_var_new:0.279
# batch i:205, episode_len:23
# kl:0.01084,lr_multiplier:0.132,loss:3.7638773918151855,entropy:3.1410744190216064,explained_var_old:0.297,explained_var_new:0.335
# batch i:206, episode_len:21
# kl:0.01435,lr_multiplier:0.132,loss:3.723832845687866,entropy:3.1019201278686523,explained_var_old:0.307,explained_var_new:0.336
# batch i:207, episode_len:18
# kl:0.01200,lr_multiplier:0.132,loss:3.628694534301758,entropy:3.0225884914398193,explained_var_old:0.379,explained_var_new:0.409
# batch i:208, episode_len:23
# kl:0.00895,lr_multiplier:0.198,loss:3.790022373199463,entropy:3.0933194160461426,explained_var_old:0.285,explained_var_new:0.313
# batch i:209, episode_len:21
# kl:0.02598,lr_multiplier:0.198,loss:3.7205891609191895,entropy:3.170602321624756,explained_var_old:0.315,explained_var_new:0.375
# batch i:210, episode_len:27
# kl:0.03200,lr_multiplier:0.198,loss:3.6423139572143555,entropy:3.0538485050201416,explained_var_old:0.366,explained_var_new:0.417
# batch i:211, episode_len:12
# kl:0.01786,lr_multiplier:0.198,loss:3.6703317165374756,entropy:3.0281403064727783,explained_var_old:0.296,explained_var_new:0.354
# batch i:212, episode_len:33
# kl:0.02050,lr_multiplier:0.198,loss:3.7271080017089844,entropy:3.0323383808135986,explained_var_old:0.343,explained_var_new:0.383
# batch i:213, episode_len:31
# kl:0.01472,lr_multiplier:0.198,loss:3.5979671478271484,entropy:3.1035451889038086,explained_var_old:0.364,explained_var_new:0.438
# batch i:214, episode_len:49
# kl:0.01786,lr_multiplier:0.198,loss:3.6613259315490723,entropy:3.0088813304901123,explained_var_old:0.258,explained_var_new:0.345
# batch i:215, episode_len:22
# kl:0.02642,lr_multiplier:0.198,loss:3.6634268760681152,entropy:3.095904588699341,explained_var_old:0.353,explained_var_new:0.409
# batch i:216, episode_len:34
# kl:0.04067,lr_multiplier:0.132,loss:3.642554998397827,entropy:3.003462791442871,explained_var_old:0.338,explained_var_new:0.367
# batch i:217, episode_len:37
# kl:0.02525,lr_multiplier:0.132,loss:3.7509684562683105,entropy:3.1246912479400635,explained_var_old:0.306,explained_var_new:0.332
# batch i:218, episode_len:18
# kl:0.01974,lr_multiplier:0.132,loss:3.6544411182403564,entropy:3.0560801029205322,explained_var_old:0.369,explained_var_new:0.395
# batch i:219, episode_len:26
# kl:0.01656,lr_multiplier:0.132,loss:3.7169084548950195,entropy:3.070255756378174,explained_var_old:0.262,explained_var_new:0.315
# batch i:220, episode_len:21
# kl:0.02177,lr_multiplier:0.132,loss:3.649057149887085,entropy:3.108002185821533,explained_var_old:0.315,explained_var_new:0.367
# batch i:221, episode_len:21
# kl:0.03327,lr_multiplier:0.132,loss:3.657165050506592,entropy:2.9723339080810547,explained_var_old:0.292,explained_var_new:0.325
# batch i:222, episode_len:20
# kl:0.02972,lr_multiplier:0.132,loss:3.5706820487976074,entropy:2.949594259262085,explained_var_old:0.262,explained_var_new:0.341
# batch i:223, episode_len:17
# kl:0.01725,lr_multiplier:0.132,loss:3.6518735885620117,entropy:2.9422607421875,explained_var_old:0.266,explained_var_new:0.293
# batch i:224, episode_len:22
# kl:0.01336,lr_multiplier:0.132,loss:3.811800003051758,entropy:3.145695686340332,explained_var_old:0.276,explained_var_new:0.339
# batch i:225, episode_len:27
# kl:0.02260,lr_multiplier:0.132,loss:3.7312138080596924,entropy:3.042482614517212,explained_var_old:0.239,explained_var_new:0.257
# batch i:226, episode_len:22
# kl:0.02448,lr_multiplier:0.132,loss:3.6581549644470215,entropy:2.9497809410095215,explained_var_old:0.257,explained_var_new:0.339
# batch i:227, episode_len:23
# kl:0.02288,lr_multiplier:0.132,loss:3.7293169498443604,entropy:3.0835306644439697,explained_var_old:0.254,explained_var_new:0.274
# batch i:228, episode_len:19
# kl:0.04041,lr_multiplier:0.088,loss:3.5544416904449463,entropy:2.871751308441162,explained_var_old:0.335,explained_var_new:0.384
# batch i:229, episode_len:18
# kl:0.02227,lr_multiplier:0.088,loss:3.7643346786499023,entropy:3.1298422813415527,explained_var_old:0.280,explained_var_new:0.301
# batch i:230, episode_len:22
# kl:0.00808,lr_multiplier:0.132,loss:3.601703643798828,entropy:3.0694026947021484,explained_var_old:0.317,explained_var_new:0.342
# batch i:231, episode_len:22
# kl:0.01656,lr_multiplier:0.132,loss:3.7501022815704346,entropy:2.9462714195251465,explained_var_old:0.174,explained_var_new:0.213
# batch i:232, episode_len:27
# kl:0.01550,lr_multiplier:0.132,loss:3.7214510440826416,entropy:3.0409700870513916,explained_var_old:0.231,explained_var_new:0.267
# batch i:233, episode_len:22
# kl:0.02863,lr_multiplier:0.132,loss:3.581357479095459,entropy:2.9499692916870117,explained_var_old:0.322,explained_var_new:0.340
# batch i:234, episode_len:16
# kl:0.01791,lr_multiplier:0.132,loss:3.7226672172546387,entropy:2.9508767127990723,explained_var_old:0.143,explained_var_new:0.217
# batch i:235, episode_len:22
# kl:0.01551,lr_multiplier:0.132,loss:3.7832541465759277,entropy:2.98602294921875,explained_var_old:0.182,explained_var_new:0.222
# batch i:236, episode_len:25
# kl:0.02580,lr_multiplier:0.132,loss:3.596907377243042,entropy:2.904891014099121,explained_var_old:0.280,explained_var_new:0.313
# batch i:237, episode_len:23
# kl:0.00853,lr_multiplier:0.198,loss:3.7230775356292725,entropy:3.062366247177124,explained_var_old:0.248,explained_var_new:0.279
# batch i:238, episode_len:23
# kl:0.02445,lr_multiplier:0.198,loss:3.7587740421295166,entropy:3.033113479614258,explained_var_old:0.177,explained_var_new:0.235
# batch i:239, episode_len:25
# kl:0.03874,lr_multiplier:0.198,loss:3.644562005996704,entropy:2.8912887573242188,explained_var_old:0.249,explained_var_new:0.276
# batch i:240, episode_len:14
# kl:0.05508,lr_multiplier:0.132,loss:3.532216787338257,entropy:2.947301149368286,explained_var_old:0.241,explained_var_new:0.288
# batch i:241, episode_len:13
# kl:0.02248,lr_multiplier:0.132,loss:3.523083448410034,entropy:2.886416435241699,explained_var_old:0.288,explained_var_new:0.343
# batch i:242, episode_len:14
# kl:0.01353,lr_multiplier:0.132,loss:3.6032047271728516,entropy:2.878009796142578,explained_var_old:0.239,explained_var_new:0.269
# batch i:243, episode_len:12
# kl:0.01204,lr_multiplier:0.132,loss:3.504974365234375,entropy:2.8490183353424072,explained_var_old:0.221,explained_var_new:0.303
# batch i:244, episode_len:24
# kl:0.02876,lr_multiplier:0.132,loss:3.707493305206299,entropy:2.9570093154907227,explained_var_old:0.158,explained_var_new:0.187
# batch i:245, episode_len:19
# kl:0.03257,lr_multiplier:0.132,loss:3.6912131309509277,entropy:2.8942015171051025,explained_var_old:0.208,explained_var_new:0.232
# batch i:246, episode_len:16
# kl:0.01834,lr_multiplier:0.132,loss:3.698495626449585,entropy:2.990086078643799,explained_var_old:0.233,explained_var_new:0.263
# batch i:247, episode_len:16
# kl:0.01830,lr_multiplier:0.132,loss:3.5668423175811768,entropy:2.924596071243286,explained_var_old:0.264,explained_var_new:0.297
# batch i:248, episode_len:16
# kl:0.02664,lr_multiplier:0.132,loss:3.6397321224212646,entropy:3.017826795578003,explained_var_old:0.283,explained_var_new:0.309
# batch i:249, episode_len:18
# kl:0.05090,lr_multiplier:0.088,loss:3.5062215328216553,entropy:2.8721044063568115,explained_var_old:0.349,explained_var_new:0.369
# batch i:250, episode_len:16
# kl:0.01089,lr_multiplier:0.088,loss:3.697854995727539,entropy:2.907688617706299,explained_var_old:0.202,explained_var_new:0.221
# current self-play batch: 250
# num_playouts:1000, win: 7, lose: 3, tie:0
# 发现新的最优策略，进行策略更新
